# %%
import pandas as pd
df_anim = pd.read_csv('origine_animale.csv')
df_anim
# Out:
#       Code Domaine                      Domaine  Code zone (M49)         Zone  \
# 0              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# 1              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# 2              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# 3              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# 4              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# ...            ...                          ...              ...          ...
# 27708          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
# 27709          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
# 27710          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
# 27711          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
# 27712          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
#
#        Code Élément                                            Élément  \
# 0               645  Disponibilité alimentaire en quantité (kg/pers...
# 1               645  Disponibilité alimentaire en quantité (kg/pers...
# 2               664     Disponibilité alimentaire (Kcal/personne/jour)
# 3               664     Disponibilité alimentaire (Kcal/personne/jour)
# 4               674  Disponibilité de protéines en quantité (g/pers...
# ...             ...                                                ...
# 27708           684  Disponibilité de matière grasse en quantité (g...
# 27709           645  Disponibilité alimentaire en quantité (kg/pers...
# 27710           664     Disponibilité alimentaire (Kcal/personne/jour)
# 27711           674  Disponibilité de protéines en quantité (g/pers...
# 27712           684  Disponibilité de matière grasse en quantité (g...
#
#       Code Produit (FBS)                   Produit  Code année  Année  \
# 0                  S2731          Viande de Bovins        2018   2018
# 1                  S2731          Viande de Bovins        2019   2019
# 2                  S2731          Viande de Bovins        2018   2018
# 3                  S2731          Viande de Bovins        2019   2019
# 4                  S2731          Viande de Bovins        2018   2018
# ...                  ...                       ...         ...    ...
# 27708              S2767        Mollusques, Autres        2019   2019
# 27709              S2769  Animaux Aquatiques Autre        2019   2019
# 27710              S2769  Animaux Aquatiques Autre        2019   2019
# 27711              S2769  Animaux Aquatiques Autre        2019   2019
# 27712              S2769  Animaux Aquatiques Autre        2019   2019
#
#                     Unité  Valeur Symbole Description du Symbole
# 0                      kg    2.67       E         Valeur estimée
# 1                      kg    2.76       E         Valeur estimée
# 2      Kcal/personne/jour   14.92       E         Valeur estimée
# 3      Kcal/personne/jour   15.42       E         Valeur estimée
# 4         g/personne/jour    1.12       E         Valeur estimée
# ...                   ...     ...     ...                    ...
# 27708     g/personne/jour    0.00       E         Valeur estimée
# 27709                  kg    0.00       E         Valeur estimée
# 27710  Kcal/personne/jour    0.00       E         Valeur estimée
# 27711     g/personne/jour    0.00       E         Valeur estimée
# 27712     g/personne/jour    0.00       E         Valeur estimée
#
# [27713 rows x 14 columns]

# %%
df_veg = pd.read_csv('origine_vegetale.csv')
df_veg
# Out:
#       Code Domaine                      Domaine  Code zone (M49)         Zone  \
# 0              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# 1              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# 2              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# 3              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# 4              FBS  Bilans Alimentaires (2010-)                4  Afghanistan
# ...            ...                          ...              ...          ...
# 92228          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
# 92229          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
# 92230          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
# 92231          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
# 92232          FBS  Bilans Alimentaires (2010-)              716     Zimbabwe
#
#        Code Élément                                            Élément  \
# 0               645  Disponibilité alimentaire en quantité (kg/pers...
# 1               645  Disponibilité alimentaire en quantité (kg/pers...
# 2               664     Disponibilité alimentaire (Kcal/personne/jour)
# 3               664     Disponibilité alimentaire (Kcal/personne/jour)
# 4               674  Disponibilité de protéines en quantité (g/pers...
# ...             ...                                                ...
# 92228           664     Disponibilité alimentaire (Kcal/personne/jour)
# 92229           674  Disponibilité de protéines en quantité (g/pers...
# 92230           674  Disponibilité de protéines en quantité (g/pers...
# 92231           684  Disponibilité de matière grasse en quantité (g...
# 92232           684  Disponibilité de matière grasse en quantité (g...
#
#       Code Produit (FBS)          Produit  Code année  Année  \
# 0                  S2511  Blé et produits        2018   2018
# 1                  S2511  Blé et produits        2019   2019
# 2                  S2511  Blé et produits        2018   2018
# 3                  S2511  Blé et produits        2019   2019
# 4                  S2511  Blé et produits        2018   2018
# ...                  ...              ...         ...    ...
# 92228              S2899     Miscellanees        2019   2019
# 92229              S2899     Miscellanees        2018   2018
# 92230              S2899     Miscellanees        2019   2019
# 92231              S2899     Miscellanees        2018   2018
# 92232              S2899     Miscellanees        2019   2019
#
#                     Unité   Valeur Symbole Description du Symbole
# 0                      kg   162.62       E         Valeur estimée
# 1                      kg   160.40       E         Valeur estimée
# 2      Kcal/personne/jour  1365.34       E         Valeur estimée
# 3      Kcal/personne/jour  1346.93       E         Valeur estimée
# 4         g/personne/jour    41.23       E         Valeur estimée
# ...                   ...      ...     ...                    ...
# 92228  Kcal/personne/jour     7.52       E         Valeur estimée
# 92229     g/personne/jour     0.19       E         Valeur estimée
# 92230     g/personne/jour     0.46       E         Valeur estimée
# 92231     g/personne/jour     0.03       E         Valeur estimée
# 92232     g/personne/jour     0.08       E         Valeur estimée
#
# [92233 rows x 14 columns]

# %%
df_pop = pd.read_csv('population.csv')
df_pop
# Out:
#     Code Domaine                      Domaine  Code zone (M49)  \
# 0            FBS  Bilans Alimentaires (2010-)                4
# 1            FBS  Bilans Alimentaires (2010-)                4
# 2            FBS  Bilans Alimentaires (2010-)              710
# 3            FBS  Bilans Alimentaires (2010-)              710
# 4            FBS  Bilans Alimentaires (2010-)                8
# ..           ...                          ...              ...
# 359          FBS  Bilans Alimentaires (2010-)              887
# 360          FBS  Bilans Alimentaires (2010-)              894
# 361          FBS  Bilans Alimentaires (2010-)              894
# 362          FBS  Bilans Alimentaires (2010-)              716
# 363          FBS  Bilans Alimentaires (2010-)              716
#
#                Zone  Code Élément            Élément Code Produit (FBS)  \
# 0       Afghanistan           511  Population totale              S2501
# 1       Afghanistan           511  Population totale              S2501
# 2    Afrique du Sud           511  Population totale              S2501
# 3    Afrique du Sud           511  Population totale              S2501
# 4           Albanie           511  Population totale              S2501
# ..              ...           ...                ...                ...
# 359           Yémen           511  Population totale              S2501
# 360          Zambie           511  Population totale              S2501
# 361          Zambie           511  Population totale              S2501
# 362        Zimbabwe           511  Population totale              S2501
# 363        Zimbabwe           511  Population totale              S2501
#
#         Produit  Code année  Année    Unité    Valeur Symbole  \
# 0    Population        2018   2018  1000 No  36686.78       X
# 1    Population        2019   2019  1000 No  37769.50       X
# 2    Population        2018   2018  1000 No  57339.64       X
# 3    Population        2019   2019  1000 No  58087.06       X
# 4    Population        2018   2018  1000 No   2877.01       X
# ..          ...         ...    ...      ...       ...     ...
# 359  Population        2019   2019  1000 No  31546.69       X
# 360  Population        2018   2018  1000 No  17835.89       X
# 361  Population        2019   2019  1000 No  18380.48       X
# 362  Population        2018   2018  1000 No  15052.18       X
# 363  Population        2019   2019  1000 No  15354.61       X
#
#                 Description du Symbole
# 0    Ciffre de sources internationales
# 1    Ciffre de sources internationales
# 2    Ciffre de sources internationales
# 3    Ciffre de sources internationales
# 4    Ciffre de sources internationales
# ..                                 ...
# 359  Ciffre de sources internationales
# 360  Ciffre de sources internationales
# 361  Ciffre de sources internationales
# 362  Ciffre de sources internationales
# 363  Ciffre de sources internationales
#
# [364 rows x 14 columns]
